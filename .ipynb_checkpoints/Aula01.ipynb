# %% [markdown]
# ## My first code on Jupyter
# ## Create a line plot
# this code shows how to create a line plot

# %%
a = [1, 2, 3, 4, 5]
b = [-1, -2, -3, -4, -5]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(a, b, color = 'purple')
plt.show()
