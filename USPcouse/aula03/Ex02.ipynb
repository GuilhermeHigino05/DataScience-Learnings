# %% [markdown]
# **EXERCÍCIO 2**
#
# Crie um array de 100 elementos e retorne apenas os valores pares

# %%
import numpy as np

# %%
arr = np.arange(0, 101)

arr_som_par = np.sum(arr[arr %2 == 0])
print(arr_som_par)
# Out:
# 2550
